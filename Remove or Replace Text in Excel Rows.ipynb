# %%
import pandas as pd

df = pd.read_excel("Batch Skip tracing final.xlsx")
df['Zip Code'] = df['Mailing Address'].str[-10:-5]  
df.to_excel("Output.xlsx")
df
# Out:
#                                     Mailing Address    Property Address  \
# 0      107 Suffield St Windsor Locks CT  06096-1337        62 Wells Rd.
# 1    29 Batterson Park Rd Farmington CT  06032-2555  16 Cedar Ridge Dr.
# 2          33 Banfield Ln Bloomfield CT  06002-2806    33 Banfield Lane
# 3          33 Banfield Ln Bloomfield CT  06002-2806    33 BANFIELD Lane
# 4       256 Alexander Rd New Britain CT  06053-1048     69 Columbia St.
# ..                                              ...                 ...
# 248           58 Fenwick St Hartford CT  06114-3013      58 Fenwick St.
# 249          7 McKenna Dr Middletown CT  06457-4013      81 Seymour St.
# 250          361 Divinity St Bristol CT  06010-6065    361 Divinity St.
# 251           PO Box 471 Glastonbury CT  06033-0471         359 Oak St.
# 252          85 Cooper St Manchester CT  06040-4959     86 Prospect St.
#
#     Property City Property State First Name       Last Name Zip Code
# ...
